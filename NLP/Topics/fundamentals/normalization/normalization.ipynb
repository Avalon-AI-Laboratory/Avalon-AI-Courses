# %% [markdown]
# # 🧼 Normalization

# %% [markdown]
# Before tokenizing text, it's often beneficial to normalize it. Normalization is the process of converting a text to a more uniform or canonical form. This helps in reducing the vocabulary size and consolidating words that have the same meaning but are represented differently. Check out the [notes](./normalization.md) for more explanations.
#
# In this notebook, we'll primarily be using NLTK for the library of choice.

# %% [markdown]
# ## Normalization Flowchart
#
# Here is a flowchart illustrating a normalization process we'll try out:
#
# ```mermaid
# graph TD
#     A[Start] --> B{Raw Text};
#     B --> C{Lowercasing};
#     C --> D{Removing Punctuation};
#     D --> E{Removing Stop Words};
#     E --> F{Stemming/Lemmatization};
#     F --> G[Normalized Text];
# ```

# %% [markdown]
# ## Lowercasing
#
# Converting all characters to lowercase. For example, "The" and "the" become the same word. Unifying the casing would allow for us to consolidate words even if they're typed "weirdly" or "WeIRdLY" (heh, get it?).

# %%
text = "The quick Brown Fox"
lower_text = text.lower()
print(lower_text)
# Out:
# the quick brown fox

# %% [markdown]
# ## Removing Punctuation
#
# Straightforward, removing punctuation marks from the text. This is especially when your task doesn't inherently concern punctuations, which would allow for your model to focus _only_ on the semantically-significant data points, that being the words.

# %%
import string
import re

text = "Hello, world! This is a test."
no_punct_text = "".join(c for c in text if c not in string.punctuation)
print(no_punct_text)

# OR, you can also do smth like

text = "Hello, world! This is a test."
no_punct_text = re.sub(r"[^\w\s]", "", text)
print(no_punct_text)
# Out:
# Hello world This is a test
# Hello world This is a test

# %% [markdown]
# ## Removing Stop Words
#
# Stop words are common words that don't carry much meaning, such as "the", "a", and "is". These words are essentially equivalent to noise, they don't add substantial information and they take up space. Each language has their own stop word lists, as the semantically-insignificant words differ from language to language, depending on their syntactical structure and vocabulary.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "This is a sample sentence, showing off the stop words filtration."
stop_words = set(stopwords.words("english"))
print(f"EN Stop Words: {stop_words}")
stop_words_id = set(stopwords.words("indonesian"))
print(f"ID Stop Words: {stop_words_id}")

word_tokens = word_tokenize(text)
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

print(filtered_sentence)
# Out:
# EN Stop Words: {'am', "you'll", 'won', "don't", "hadn't", 'of', 'on', 'any', "it'll", 'weren', 'it', 'mightn', 's', 'the', "he'll", 'so', 'their', 'yourself', 'mustn', 'you', 'below', 'if', 'him', 'has', 'theirs', 'at', "haven't", 'which', 'me', 'doing', "he's", 'both', 'no', 'not', 'who', 'his', 'by', "mustn't", 'why', 'being', 'own', "she's", 'd', "mightn't", 'through', 'to', 'itself', 'too', "we'd", 'about', 'himself', 'further', 'ain', "shouldn't", 'hasn', 'for', "weren't", 'your', 'her', 'and', 'until', "we're", "couldn't", "i've", 'had', 've', "you'd", 'while', 'what', 'shan', 'o', 'very', 'where', "he'd", "they've", 'during', "didn't", 'herself', "wouldn't", 'only', "they're", "that'll", "i'm", "i'll", 'hers', 'before', 'having', 'we', 'but', 'here', 'is', 'an', 'them', 't', 'other', 'over', 'each', 'with', "isn't", "they'd", 'i', 'nor', 'whom', 'she', 'yours', 'then', 'are', 'ours', 'our', "it's", 'a', 'in', 'now', 'when', 'above', 'they', "i'd", 'or', 'same', "it'd", 'isn', 'than', 'can', "shan't", 'should', "she'll", 'under', 'didn', 'wouldn', "she'd", 'm', "needn't", "hasn't", 'don', 'themselves', 'ma', 'from', 'all', 'as', 'down', 'do', 'once', "we'll", "you're", 'y', 'haven', 'myself', 'needn', 'some', 'shouldn', 'such', 'after', 'just', 'up', 'most', 'yourselves', 'aren', 'this', 'couldn', "aren't", 'wasn', 'off', 're', 'be', 'because', 'ourselves', "wasn't", "you've", "we've", 'few', 'again', "they'll", "won't", "should've", 'were', "doesn't", 'will', 'been', 'against', 'hadn', 'more', 'was', 'have', 'its', 'does', 'he', 'll', 'between', 'these', 'out', 'that', 'my', 'there', 'into', 'those', 'did', 'doesn', 'how'}
# ID Stop Words: {'berjumlah', 'para', 'masing-masing', 'memisalkan', 'tahu', 'inginkan', 'yaitu', 'tertuju', 'harusnya', 'disini', 'menjadi', 'bisakah', 'mungkinkah', 'sebetulnya', 'aku', 'yakni', 'selama', 'menyiapkan', 'berupa', 'tegas', 'mulailah', 'jelasnya', 'dimaksudnya', 'berada', 'seingat', 'diberikannya', 'pertanyaan', 'sekurangnya', 'kembali', 'terdiri', 'sebab', 'terdahulu', 'berturut-turut', 'nyaris', 'haruslah', 'tersampaikan', 'bagai', 'sekitarnya', 'kamilah', 'terlebih', 'seusai', 'bahwasanya', 'dijelaskan', 'bagaimana', 'dilalui', 'entah', 'apabila', 'persoalan', 'bung', 'berakhir', 'hanyalah', 'bapak', 'memihak', 'sedang', 'keadaan', 'diperlukan', 'perlunya', 'sesudahnya', 'mirip', 'keinginan', 'diakhirinya', 'anda', 'sela', 'mendatangkan', 'berkenaan', 'mengucapkan', 'berikan', 'bersiap', 'mendapatkan', 'ditanya', 'sebutlah', 'sendiri', 'sudah', 'sebaik', 'diucapkannya', 'dikarenakan', 'akulah', 'jawabnya', 'itukah', 'pak', 'bukannya', 'berawal', 'dahulu', 'lainnya', 'meski', 'kami', 'kalaupun', 'kebetulan', 'biasa', 'menandaskan', 'mengibaratkannya', 'ditunjukkan', 'saja', 'soalnya', 'sudahlah', 'dimintai', 'bawah', 'dituturkannya', 'kelihatan', 'penting', 'kapanpun', 'untuk', 'sepantasnyalah', 'tuturnya', 'diberi', 'toh', 'serupa', 'bisa', 'sekaligus', 'dimisalkan', 'setibanya', 'melalui', 'setinggi', 'telah', 'memberi', 'kira', 'sekadarnya', 'dimungkinkan', 'menggunakan', 'diperkirakan', 'menambahkan', 'bermula', 'mempergunakan', 'memperlihatkan', 'sampai', 'sebaiknya', 'memungkinkan', 'mempersiapkan', 'berlainan', 'menjelaskan', 'bukankah', 'melihat', 'menegaskan', 'wah', 'tambahnya', 'kitalah', 'agaknya', 'dimaksudkannya', 'sebut', 'berapakah', 'berakhirlah', 'seperlunya', 'hampir', 'kok', 'sepantasnya', 'diibaratkannya', 'semakin', 'janganlah', 'menaiki', 'mungkin', 'kalaulah', 'masing', 'baru', 'inginkah', 'ditandaskan', 'bilakah', 'umum', 'mau', 'ingat-ingat', 'datang', 'bermaksud', 'secukupnya', 'beberapa', 'ia', 'wahai', 'berkehendak', 'cuma', 'suatu', 'lagian', 'tampak', 'kurang', 'lama', 'kelihatannya', 'perlu', 'beri', 'berarti', 'jauh', 'diantaranya', 'dong', 'pasti', 'menanti-nanti', 'dikira', 'saya', 'seseorang', 'tidakkah', 'kinilah', 'meyakinkan', 'menyeluruh', 'mampu', 'macam', 'ialah', 'mengakhiri', 'sekitar', 'supaya', 'berkata', 'seberapa', 'bagaikan', 'kalau', 'ataupun', 'diakhiri', 'sepanjang', 'diberikan', 'dimulai', 'punya', 'bersama', 'terasa', 'bulan', 'pentingnya', 'cukuplah', 'bahkan', 'banyak', 'ibu', 'segala', 'dini', 'kala', 'sangatlah', 'sambil', 'ditunjuknya', 'menuju', 'sedikit', 'dilakukan', 'belakangan', 'diperbuatnya', 'berikutnya', 'sampaikan', 'demikian', 'semisal', 'sebisanya', 'mulanya', 'katakanlah', 'bermacam', 'satu', 'dijelaskannya', 'jika', 'makanya', 'tidak', 'depan', 'jikalau', 'lebih', 'menyangkut', 'mengungkapkan', 'naik', 'merasa', 'bolehlah', 'tidaklah', 'sini', 'awalnya', 'sekiranya', 'diri', 'kamulah', 'berikut', 'justru', 'tegasnya', 'selain', 'benar', 'dimulainya', 'lamanya', 'enggaknya', 'terhadapnya', 'lalu', 'sebabnya', 'ucap', 'apatah', 'ikut', 'lima', 'manakala', 'mengira', 'kedua', 'balik', 'tadinya', 'meminta', 'tertentu', 'disebutkannya', 'sedemikian', 'sekali-kali', 'siapapun', 'teringat-ingat', 'menjawab', 'sekalipun', 'didapat', 'seterusnya', 'juga', 'begitukah', 'amat', 'jangankan', 'bagi', 'turut', 'sangat', 'sekadar', 'berapalah', 'hal', 'dikatakannya', 'siap', 'dimulailah', 'mereka', 'berlalu', 'sayalah', 'misalkan', 'begitulah', 'semua', 'mengapa', 'hendaklah', 'mengingatkan', 'sinilah', 'sebegitu', 'menuturkan', 'berkali-kali', 'hendaknya', 'lanjutnya', 'ada', 'sesuatu', 'sempat', 'kelima', 'sejumlah', 'kira-kira', 'rasanya', 'daripada', 'asal', 'mempersoalkan', 'mempertanyakan', 'makin', 'mengingat', 'dipergunakan', 'memperkirakan', 'sekecil', 'berbagai', 'tengah', 'diucapkan', 'agak', 'belum', 'betul', 'dalam', 'dekat', 'misalnya', 'padahal', 'pukul', 'tentunya', 'kenapa', 'malah', 'memintakan', 'terbanyak', 'bersiap-siap', 'dikerjaka ...
# ['sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %% [markdown]
# ## Stemming
#
# Stemming reduce words to their "root" form. For example, "running", "ran", and "runner" might all be stemmed to "run". There are a few Stemmers that one could use from NLTK for each of these, they have their own definitions of what constitutes a "root".

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["program", "programming", "programmer", "programs", "programmed"]

stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['program', 'program', 'programm', 'program', 'program']

# %% [markdown]
# ## Lemmatization
#
# Similar to stemming, but it reduces words to their dictionary form (lemma). A huge difference between this and stemming is that, lemmatization _needs_ context. This is because lemmatization tries to work backward from semantics to the word's "core" form.
#
# Here, we'll use a WordNet-based (which is a learned function) lemmatizer, but lemmatization doesn't have to be done as a learned function.

# %%
import nltk

nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kek\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()
words = ["program", "programming", "programmer", "programs", "programmed"]

lemmatized_words = [lemmatizer.lemmatize(word, pos="v") for word in words]
print(lemmatized_words)

lemmatized_words = [lemmatizer.lemmatize(word, pos="a") for word in words]
print(lemmatized_words)
# Out:
# ['program', 'program', 'programer', 'program', 'program']
# ['program', 'programming', 'programer', 'programs', 'programmed']
